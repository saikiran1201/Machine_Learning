# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd()
# Out:
# 'c:\\Users\\saikiran\\Desktop\\py\\ML\\linear_regg'

# %%
df = pd.read_csv("C:\\Users\\saikiran\\Desktop\\py\\Udemy_ML\\DATA\\Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
#df['advt'] = df["TV"] + df["newspaper"] + df["radio"]
#df

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))

plt.subplot(1, 4, 1)
plt.scatter(df["TV"], df["sales"])
plt.title("sales vs TV")

plt.subplot(1, 4, 2)
plt.scatter(df["radio"], df["sales"])
plt.title("sales vs radio")

plt.subplot(1, 4, 3)
plt.scatter(df["newspaper"], df["sales"])
plt.title("sales vs newspaper")



plt.show()
plt.tight_layout();

# %%
df.corr(method='pearson')
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
# Relationships between features
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# Introducing SciKit Learn

# %%
X = df.drop('sales',axis=1)
y = df['sales']

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
len(df)
# Out:
# 200

# %%
X_train
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
X_test
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
len(X_test)
# Out:
# 60

# %%
from sklearn.linear_model import LinearRegression

# %%
#help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_pred = model.predict(X_test)
test_pred
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df["sales"].mean()
# Out:
# 14.0225

# %%
sns.histplot(data=df, x="sales")
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %%
from sklearn.metrics import r2_score
r2 = r2_score(test_pred, y_test)
print('The rsquared value is: ' + str(round(r2, 3)))
# Out:
# The rsquared value is: 0.903

# %%
mean_absolute_error(y_test, test_pred)
# Out:
# 1.213745773614481

# %%
#10 percent error when compare with the avg
#msE is varience of predictions
mean_squared_error(y_test, test_pred)
# Out:
# 2.2987166978863796

# %%
#RMSE is sd of pedictions
np.sqrt(mean_squared_error(y_test, test_pred))
# Out:
# 1.5161519375993884

# %%
test_resuduals = y_test - test_pred
test_resuduals
# Out:
# 37    -1.041313
# 109    0.189374
# 31     0.451111
# 89    -0.308198
# 66     0.327143
# 119   -0.412483
# 54    -0.089925
# 74    -0.299540
# 145    0.524155
# 142    0.878058
# 148   -1.505032
# 112    0.207650
# 174   -2.225411
# 55     2.412060
# 141    0.775434
# 149    0.118016
# 25    -3.552290
# 34     1.810863
# 170    0.843850
# 39     1.096888
# 172   -0.192152
# 153    0.757859
# 175    2.313681
# 61     1.378009
# 65     1.320379
# 50    -1.252073
# 42    -0.769259
# 129    1.647714
# 179    0.176840
# 2     -3.207197
# 12    -1.577578
# 133    0.355399
# 90     1.129731
# 22    -1.107800
# 41    -0.214921
# 32     1.832357
# 125    1.346067
# 196    1.421653
# 158   -3.281056
# 180   -0.135911
# 16    -0.510026
# 186    0.528079
# 144    1.185301
# 121   -1.045720
# 80     0.232893
# 18     1.216320
# 78    -3.698066
# 48    -1.453889
# 4     -0.339423
# 15     1.585066
# 1     -2.097274
# 43    -1.066159
# 102   -2.762851
# 164    0.754630
# 9     -1.962615
# ...

# %%
sns.scatterplot(x= y_test, y = test_resuduals)
#random
plt.axhline(y = 0, color = "r", ls="--")

# %%
sns.displot(test_resuduals,bins=25 ,kde = "True")

# %% [markdown]
# Still unsure if normality is a reasonable approximation? We can check against the normal probability plot.

# %%
import scipy as sp
# Create a figure and axis to plot on
fig, ax = plt.subplots(figsize=(6,8),dpi=100)
# probplot returns the raw values if needed
# we just want to see the plot, so we assign these values to _
_ = sp.stats.probplot(test_resuduals,plot=ax)

# %% [markdown]
# Deployment, Predictions, and Model Attributes

# %%
df.dropna(inplace=True)

# %%
final_model = LinearRegression()
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_hat = final_model.predict(X)

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(20,8))

plt.subplot(1, 3, 1)
plt.scatter(df["TV"], df["sales"])
plt.scatter(df['TV'], y_hat,color='red')
plt.title("sales vs TV")

plt.subplot(1, 3, 2)
plt.scatter(df['radio'],y_hat,color='red')
plt.scatter(df["radio"], df["sales"])
plt.title("sales vs radio")

plt.subplot(1, 3, 3)
plt.scatter(df['newspaper'], y_hat,color='red')
plt.scatter(df["newspaper"], df["sales"])
plt.title("sales vs newspaper")



plt.show()
#plt.tight_layout();

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4
